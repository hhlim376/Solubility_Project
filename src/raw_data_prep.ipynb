# %%
import pandas as pd
import numpy as np

# %%
## Read Delaney Data into dataframe
df_delaney = pd.read_csv("ci034243xsi20040112_053635.txt")

# %%
df_delaney
# Out:
#                          Compound ID  measured log(solubility:mol/L)  \
# 0          1,1,1,2-Tetrachloroethane                          -2.180
# 1              1,1,1-Trichloroethane                          -2.000
# 2          1,1,2,2-Tetrachloroethane                          -1.740
# 3              1,1,2-Trichloroethane                          -1.480
# 4     1,1,2-Trichlorotrifluoroethane                          -3.040
# ...                              ...                             ...
# 1139                     vamidothion                           1.144
# 1140                     Vinclozolin                          -4.925
# 1141                        Warfarin                          -3.893
# 1142                        Xipamide                          -3.790
# 1143                             XMC                          -2.581
#
#       ESOL predicted log(solubility:mol/L)  \
# 0                                   -2.794
# 1                                   -2.232
# ...

# %%
df_delaney.loc[df_delaney['measured log(solubility:mol/L)'] == -6.98]
# Out:
#                   Compound ID  measured log(solubility:mol/L)  \
# 13  1,2,4,5-Tetrabromobenzene                           -6.98
#
#     ESOL predicted log(solubility:mol/L)                SMILES
# 13                                -6.001  Brc1cc(Br)c(Br)cc1Br

# %%
## Save to csv
# df_delaney.to_csv("data_delaney.csv", index = False)

# %%
## Read Sol Data into dataframe
df_sol = pd.read_excel("soldataswap.xls")

# %%
# df_sol.to_csv('data_sol.csv', index = False)

# %%
df_sol.columns
# Out:
# Index(['Substance', 'Temperature', 'assays', 'Ionic Strength (M)', 'S0 (mM)',
#        'SD of S0 (mM)', 'Kinetic Solubility (mM)',
#        'SD of Kinetic Solubility (mM)', 'Unnamed: 8', 'Unnamed: 9', 'SMILES',
#        'InChI'],
#       dtype='object')

# %%
## Read Wang Data into dataframes and combine data
dfw1 = pd.read_excel("ci800406y_si_001.xls")
dfw2 = pd.read_excel("ci800406y_si_002.xls")
dfw3 = pd.read_excel("ci800406y_si_003.xls")
dfw4 = pd.read_excel("ci800406y_si_004.xls")
dfw5 = pd.read_excel("ci800406y_si_005.xls")

# %%
dfw1
# Out:
#      Table S1. List of the experimental and predicted aqueous solubilities by the four models for Data Set 1  \
# 0                                                   NaN
# 1                                                    No
# 2                                                     1
# 3                                                     2
# 4                                                     3
# ...                                                 ...
# 1710                                    Data Source IDs
# 1711                                                  1
# 1712                                                  2
# 1713                                                  3
# 1714                                                  4
#
#                    Unnamed: 1 Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 0                         NaN        NaN             NaN  ASM-ATC-LOGP
# 1                       Expt.      ClogP  Polarizability     Predicted
# ...

# %%
## Clean up headers
df_list = [dfw1, dfw2, dfw3, dfw4, dfw5]
for df in df_list:
    df.columns = df.iloc[1]
    df.drop(df.index[:2], inplace=True)

# %%
## Drop nulls
for df in df_list:
    df.dropna(inplace = True)

# %%
## Reindex
for i in range(len(df_list)):
    df_list[i] = df_list[i].reset_index(drop=True)

# %%
## Drop samples from delaney dataset
dfw1 = dfw1[dfw1['Data Source ID'] != 2]

# %%
dfw1
# Out:
# 1       No Expt. ClogP Polarizability Predicted Residual Predicted Residual  \
# 2        1 -4.35  4.22        133.981   -3.7955  -0.5545   -3.7035  -0.6465
# 3        2 -3.33  2.95        130.274   -3.9317   0.6017   -3.8706   0.5406
# 5        4 -6.09  5.07         193.29   -5.6505  -0.4395   -5.5381  -0.5519
# 7        6  -4.5  4.38        133.603   -4.4934  -0.0066   -4.5629   0.0629
# 8        7 -5.04  4.22        133.603   -4.4712  -0.5688   -4.6013  -0.4387
# ...    ...   ...   ...            ...       ...      ...       ...      ...
# 1701  1700 -5.54  5.07        253.429   -5.5664   0.0264   -5.3289  -0.2111
# 1704  1703  -4.1  2.84        205.857   -5.0148   0.9148    -4.757    0.657
# 1705  1704 -3.37  2.93        207.793   -3.6807   0.3107    -3.618    0.248
# 1708  1707 -4.86  3.88        231.571   -3.8584  -1.0016   -3.8146  -1.0454
# 1709  1708  -3.9  1.75        181.635   -2.5463  -1.3537   -2.5723  -1.3277
#
# ...

# %%
# dfw1.to_csv("w1.csv", index = False)
# dfw2.to_csv("w2.csv", index = False)
# dfw3.to_csv("w3.csv", index = False)
# dfw4.to_csv("w4.csv", index = False)
# dfw5.to_csv("w5.csv", index = False)

# %%
## Drop datasource id column from dfw1
# dfw1.drop(columns = ['Data Source ID'], inplace = True)

# %%
for df in df_list:
    print (df.columns)
# Out:
# Index(['No', 'Expt.', 'ClogP', 'Polarizability', 'Predicted', 'Residual',
#        'Predicted', 'Residual', 'Predicted', 'Residual', 'Predicted',
#        'Residual', 'Data Source ID', 'Name', 'SLN'],
#       dtype='object', name=1)
# Index(['No', 'Expt.', 'ClogP', 'Tm', 'Polarizability', 'Predicted', 'Residual',
#        'Predicted', 'Residual', 'Predicted', 'Residual', 'Predicted',
#        'Residual', 'Name', 'SLN'],
#       dtype='object', name=1)
# Index(['No', 'Expt.', 'ClogP', 'Polarizability', 'Predicted', 'Residual',
#        'Predicted', 'Residual', 'Predicted', 'Residual', 'Predicted',
#        'Residual', 'Name', 'SLN'],
#       dtype='object', name=1)
# Index(['No', 'Entry', 'Expt.', 'ClogP', 'Polarizability', 'Predicted',
#        'Residual', 'Predicted', 'Residual', 'Predicted', 'Residual',
#        'Predicted', 'Residual', 'SLN'],
#       dtype='object', name=1)
# Index(['No', 'Expt.', 'ClogP', 'MP', 'Polarizability', 'Predicted', 'Residual',
# ...

# %%
dfw1 = dfw1[['Expt.','SLN']]
dfw2 = dfw2[['Expt.', 'SLN']]
dfw3 = dfw3[['Expt.', 'SLN']]
dfw4 = dfw4[['Expt.', 'SLN']]
dfw5 = dfw5[['Expt.', 'SLN']]

# %%
df_list = [dfw1, dfw2, dfw3, dfw4, dfw5]

# %%
## Combine dataframes
dfw_combined = pd.concat(df_list)

# %%
dfw_combined = dfw_combined.reset_index(drop=True)

# %%
dfw_combined
# Out:
# 1      Expt.                                                SLN
# 0      -4.35               BrC[2]C[3]=C(CH=CHCH=@2)CH=CHCH=CH@3
# 1      -3.33                    BrC[2]=C(C(=CHC(=CH@2)C#N)Br)OH
# 2      -6.09       BrC[2]=C(CH=C(C(=CH@2)Cl)OP(=S)(OCH3)OCH3)Cl
# 3       -4.5                        BrC[2]=C(CH=CHC(=CH@2)Br)Br
# 4      -5.04                          BrC[2]=C(CH=CHCH=C@2Br)Br
# ...      ...                                                ...
# 3346 -3.3319  C[1]H=C(CH=CHC(=CH@1)C(=O)C[13]=CHCH=C(S@13)S(...
# 3347 -2.1669  C[1]H=C(CH=CHC(=CH@1)C(=O)C[13]=CHCH=C(S@13)S(...
# 3348 -1.4812  C[1]H=C(CH=CHC(=CH@1)C(=O)C[13]=CHCH=C(S@13)S(...
# 3349 -1.8802  C[1]H=C(CH=CHC(=CH@1)C(=O)C[13]=CHCH=C(S@13)S(...
# 3350 -1.0324  C[1]H=C(C(=CHC(=CH@1)C(=O)C[12]=CHCH=C(S@12)S(...
#
# [3351 rows x 2 columns]

# %%
dfw_combined.to_csv("data_wang.csv", index = False)
